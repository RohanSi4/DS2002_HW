# %%
import requests
import json
import pandas as pd

# API endpoint for fetching universities
url = "http://universities.hipolabs.com/search?country=United%20States"

# Make the GET request
response = requests.get(url)

# Check the status code
if response.status_code == 200:
    print("API request successful!")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# API request successful!

# %%
# Parse the JSON response
university_data = response.json()

# Pretty-print the first university
print(json.dumps(university_data[0], indent=2))
# Out:
# {
#   "country": "United States",
#   "name": "Marywood University",
#   "state-province": null,
#   "alpha_two_code": "US",
#   "web_pages": [
#     "http://www.marywood.edu"
#   ],
#   "domains": [
#     "marywood.edu"
#   ]
# }

# %%
# Convert JSON data to a DataFrame
df = pd.DataFrame(university_data)

# Display the first few rows of the DataFrame
print(df.head())
df
# Out:
#          country                                   name state-province  \
# 0  United States                    Marywood University           None
# 1  United States                  Lindenwood University           None
# 2  United States                    Sullivan University           None
# 3  United States  Florida State College at Jacksonville           None
# 4  United States                      Xavier University           None
#
#   alpha_two_code                     web_pages           domains
# 0             US     [http://www.marywood.edu]    [marywood.edu]
# 1             US  [http://www.lindenwood.edu/]  [lindenwood.edu]
# 2             US       [https://sullivan.edu/]    [sullivan.edu]
# 3             US       [https://www.fscj.edu/]        [fscj.edu]
# 4             US     [https://www.xavier.edu/]      [xavier.edu]
#             country                                   name state-province  \
# 0     United States                    Marywood University           None
# 1     United States                  Lindenwood University           None
# 2     United States                    Sullivan University           None
# 3     United States  Florida State College at Jacksonville           None
# 4     United States                      Xavier University           None
# ...             ...                                    ...            ...
# 2334  United States            South Florida State College        Florida
# 2335  United States                    Alvernia University   Pennsylvania
# 2336  United States           Hellenic American University           None
# 2337  United States               University of Holy Cross           None
# 2338  United States                University of Pikeville           None
#
#      alpha_two_code                        web_pages             domains
# 0                US        [http://www.marywood.edu]      [marywood.edu]
# 1                US     [http://www.lindenwood.edu/]    [lindenwood.edu]
# 2                US          [https://sullivan.edu/]      [sullivan.edu]
# 3                US          [https://www.fscj.edu/]          [fscj.edu]
# 4                US        [https://www.xavier.edu/]        [xavier.edu]
# ...             ...                              ...                 ...
# 2334             US  [https://www.southflorida.edu/]  [southflorida.edu]
# 2335             US      [https://www.alvernia.edu/]      [alvernia.edu]
# 2336             US        [https://www.hauniv.edu/]        [hauniv.edu]
# 2337             US             [https://uhcno.edu/]         [uhcno.edu]
# 2338             US         [https://www.upike.edu/]         [upike.edu]
#
# [2339 rows x 6 columns]

# %%
# Count the number of universities by state
state_counts = df['state-province'].value_counts()
print(state_counts)
# Out:
# state-province
# Pennsylvania            32
# NY                       9
# California               5
# Texas                    5
# New York, NY             4
# New York                 3
# Florida                  3
# North Carolina           3
# Michigan                 3
# Ohio                     3
# Illinois                 2
# CA                       2
# Washington               2
# GA                       2
# TX                       2
# ND                       1
# Missouri                 1
# Maine                    1
# MA                       1
# Georgia                  1
# MI                       1
# New Hampshire            1
# Virginia                 1
# South Carolina           1
# IN                       1
# Colorado                 1
# Kansas                   1
# Indiana                  1
# VA                       1
# Iowa                     1
# NV                       1
# Utah                     1
# Salt Lake City, Utah     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Plot the number of universities per state
state_counts.plot(kind='bar', figsize=(10, 6))
plt.title("Number of Universities per State")
plt.xlabel("State")
plt.ylabel("Number of Universities")
plt.show()

# %%
countries = ["United States", "Canada", "Australia", "United Kingdom"]
university_list = []

for country in countries:
    response = requests.get(f"http://universities.hipolabs.com/search?country={country}")
    data = response.json()

    for uni in data:
        uni['country'] = country
        university_list.append(uni)

# Convert to DataFrame
df_universities = pd.DataFrame(university_list)

# Display the first few rows
print(df_universities.head())
# Out:
#          country                                   name state-province  \
# 0  United States                    Marywood University           None
# 1  United States                  Lindenwood University           None
# 2  United States                    Sullivan University           None
# 3  United States  Florida State College at Jacksonville           None
# 4  United States                      Xavier University           None
#
#   alpha_two_code                     web_pages           domains
# 0             US     [http://www.marywood.edu]    [marywood.edu]
# 1             US  [http://www.lindenwood.edu/]  [lindenwood.edu]
# 2             US       [https://sullivan.edu/]    [sullivan.edu]
# 3             US       [https://www.fscj.edu/]        [fscj.edu]
# 4             US     [https://www.xavier.edu/]      [xavier.edu]

# %%
# Count the number of universities per country
country_counts = df_universities['country'].value_counts()

# Plot the data
country_counts.plot(kind='bar', figsize=(10, 6))
plt.title("Number of Universities per Country")
plt.xlabel("Country")
plt.ylabel("Number of Universities")
plt.show()

# %%
import json
import pandas as pd
import json
import requests

# %%
# Ask the user for a list of stock ticker symbols
stock_input = input("Enter a list of stock ticker symbols separated by commas (e.g., AAPL, MSFT, TSLA): ").strip()

# Pass the input back to the user
print(f"You entered the following stock ticker symbols: {stock_input}")
# Out:
# You entered the following stock ticker symbols: aapl, msft, tsla

# %%
apikey="key"

url = "https://yfapi.net/v6/finance/quote"

querystring = {"symbols":stock}

headers = {
    'x-api-key': apikey
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"quoteResponse":{"result":[{"language":"en-US","region":"US","quoteType":"EQUITY","typeDisp":"Equity","quoteSourceName":"Nasdaq Real Time Price","triggerable":true,"customPriceAlertConfidence":"HIGH","currency":"USD","sharesOutstanding":15115799552,"bookValue":3.767,"fiftyDayAverage":229.4358,"fiftyDayAverageChange":13.574188,"fiftyDayAverageChangePercent":0.05916334,"twoHundredDayAverage":206.4068,"twoHundredDayAverageChange":36.603195,"twoHundredDayAverageChangePercent":0.17733522,"marketCap":3673290440704,"forwardPE":29.243078,"priceToBook":64.510216,"sourceInterval":15,"exchangeDataDelayedBy":0,"averageAnalystRating":"1.9 - Buy","tradeable":false,"cryptoTradeable":false,"marketState":"POST","exchange":"NMS","shortName":"Apple Inc.","longName":"Apple Inc.","messageBoardId":"finmb_24937","exchangeTimezoneName":"America/New_York","exchangeTimezoneShortName":"EST","gmtOffSetMilliseconds":-18000000,"market":"us_market","esgPopulated":false,"regularMarketChangePercent":0.1483621,"regularMarketPrice":243.01,"hasPrePostMarketData":true,"firstTradeDateMilliseconds":345479400000,"priceHint":2,"postMarketChangePercent":-0.05761055,"postMarketTime":1733348795,"postMarketPrice":242.87,"postMarketChange":-0.13999939,"regularMarketChange":0.3600006,"regularMarketTime":1733346001,"regularMarketDayHigh":244.105,"regularMarketDayRange":"241.25 - 244.105","regularMarketDayLow":241.25,"regularMarketVolume":41848779,"regularMarketPreviousClose":242.65,"bid":242.85,"ask":243.09,"bidSize":3,"askSize":5,"fullExchangeName":"NasdaqGS","financialCurrency":"USD","regularMarketOpen":242.88,"averageDailyVolume3Month":48371926,"averageDailyVolume10Day":43672210,"fiftyTwoWeekLowChange":78.92999,"fiftyTwoWeekLowChangePercent":0.48104578,"fiftyTwoWeekRange":"164.08 - 244.105","fiftyTwoWeekHighChange":-1.0950012,"fiftyTwoWeekHighChangePercent":-0.0044857794,"fiftyTwoWeekLow":164.08,"fiftyTwoWeekHigh":244.105,"fiftyTwoWeekChangePercent":26.16992,"dividendDate":1731542400,"earningsTimestamp":1730406600,"earningsTimestampStart":1738270800,"earningsTimestampEnd":1738616400,"earningsCallTimestampStart":1730408400,"earningsCallTimestampEnd":1730408400,"isEarningsDateEstimate":true,"trailingAnnualDividendRate":0.98,"trailingPE":39.90312,"dividendRate":1.0,"trailingAnnualDividendYield":0.004038739,"dividendYield":0.41,"epsTrailingTwelveMonths":6.09,"epsForward":8.31,"epsCurrentYear":7.39333,"priceEpsCurrentYear":32.868813,"displayName":"Apple","symbol":"AAPL"}],"error":null}}

# %%
#print the company name and price
stock_json = response.json()
print(stock_json['quoteResponse']['result'][0]["longName"] + " Price:$" + str(stock_json['quoteResponse']['result'][0]["regularMarketPrice"]))
# Out:
# Apple Inc. Price:$243.01
